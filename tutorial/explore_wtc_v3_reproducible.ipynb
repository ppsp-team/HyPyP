# %%
# %connect_info
# Out:
# {"key":"67538b0a-993b-48d1-8344-a0d357621dca","signature_scheme":"hmac-sha256","transport":"tcp","ip":"127.0.0.1","hb_port":9005,"control_port":9006,"shell_port":9007,"stdin_port":9008,"iopub_port":9009,"kernel_name":"python3112jvsc74a57bd04149aa2f31a7f8b5ff184e82bf464dce73529b69401cc2940ad6232b832b4da8"}
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-v3da26d82b5f840a5f7fcbf42fa9003eaa73d22775.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import fft
from copy import deepcopy

# %%
# %load_ext IPython.extensions.autoreload
# %autoreload 2

import pywt
import pycwt

from hypyp.fnirs_tools import (
    xwt_coherence_morl,
    get_frequencies,
    smoothing
)
import hypyp.plots

# %% [markdown]
# ## Sine waves

# %%
plt.figure(figsize=(10,2))

fs = 5
N = 1501
T = 1.0 / fs
x = np.linspace(0, N/fs, N)

freq1 = 0.02
freq2 = freq1 - 0.0001

y1 = np.sin(x * 2 * np.pi * freq1)
y2 = np.sin(x * 2 * np.pi * freq2)

# fft
y1_fft = fft.fft(y1)
x_fft = fft.fftfreq(N, T)[:N//2]
y2_fft = fft.fft(y2)

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

plt.figure(figsize=(10,2))

plt.plot(x_fft, 2.0/N * np.abs(y1_fft[0:N//2]))
plt.plot(x_fft, 2.0/N * np.abs(y2_fft[0:N//2]))
plt.xscale('log')
plt.grid()
plt.show()

# %%
# full example

wavelet_name = 'cmor2-1'
tracer_pywt = dict(name='pywt')

wtc_pywt, times, freqs_pywt, coif_pywt = xwt_coherence_morl(
    y1,
    y2,
    T,
    1/12,
    wavelet_name=wavelet_name,
    normalize=True,
    smoothing_params=dict(smooth_factor=0, boxcar_size=1),
    tracer=tracer_pywt
)

tracer_pycwt = dict(name='pycwt')
wtc_pycwt, aWTC_pycwt, coi_pycwt, periods_pycwt, significance_pycwt = pycwt.wct(y1, y2, dt=1/fs, sig=False, tracer=tracer_pycwt)
freqs_pycwt = 1 / periods_pycwt

tracers = [tracer_pywt, tracer_pycwt]

for tracer in tracers:
    #tracer['plot_this'] = np.abs(tracer['S12']) ** 2
    #tracer['plot_this'] = np.log(tracer['S1'] * tracer['S2']) # this shows a grid artifact, very interesting
    #tracer['plot_this'] = np.log(tracer['S1']) # this shows a grid artifact, very interesting
    tracer['plot_this'] = np.log(tracer['W1']) # this shows lines artifacts


plt.show()

hypyp.plots.plot_coefs(tracers, 'plot_this', 'plot_this')
#hypyp.plots.plot_coefs(tracers, 'S12', 'S12')
#hypyp.plots.plot_coefs(tracers, 'W1', 'W1')
#hypyp.plots.plot_coefs(tracers, 'W2', 'W2')
#hypyp.plots.plot_coefs(tracers, 'W12', 'W12')
#hypyp.plots.plot_coefs(tracers, 'S1', 'S1')
#hypyp.plots.plot_coefs(tracers, 'S2', 'S2')
#hypyp.plots.plot_coefs(tracers, 'S12', 'S12')
#
hypyp.plots.plot_wavelet_coherence(np.abs(wtc_pywt), times, freqs_pywt, coif_pywt, title='pywt')
hypyp.plots.plot_wavelet_coherence(np.abs(wtc_pycwt), times, freqs_pycwt, coif_pywt, title='pycwt')

#get_frequencies(wavelet_name, freqs_pywt, T)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 wavelet_name = 'cmor2-1'
#       4 tracer_pywt = dict(name='pywt')
# ----> 6 wct_pywt, times, freqs_pywt, coif_pywt = xwt_coherence_morl(
#       7     y1,
#       8     y2,
#       9     T,
#      10     1/12,
#      11     wavelet_name=wavelet_name,
#      12     normalize=True,
#      13     smoothing_params=dict(smooth_factor=0, boxcar_size=1),
#      14     tracer=tracer_pywt
#      15 )
#      17 tracer_pycwt = dict(name='pycwt')
#      18 wct_pycwt, aWCT_pycwt, coi_pycwt, periods_pycwt, significance_pycwt = pycwt.wct(y1, y2, dt=1/fs, sig=False, tracer=tracer_pycwt)
#
# File ~/work/ppsp/HyPyP-synchro/hypyp/fnirs_tools.py:453, in xwt_coherence_morl(y1, y2, dt, dj, wavelet_name, detrend, normalize, cwt_params, smoothing_params, tracer)
#     450 nOctaves = int(np.log2(2 * np.floor(N / 2.0)))
#     451 scales = 2 ** np.arange(1, nOctaves, dj)
# --> 453 W1, _ = pywt.cwt(y1_normal, scales, wavelet_name, method='fft', tracer=tracer, **cwt_params)
#     454 W2, _ = pywt.cwt(y2_normal, scales, wavelet_name, method='fft', **cwt_params)
#     456 #frequencies = freqs1
#
# TypeError: cwt() got an unexpected keyword argument 'tracer'

# %%
for tracer in tracers:
    print(tracer['name'])
    tracer['plot_this'] = np.log(tracer['W1']) # this shows lines artifact, very interesting

hypyp.plots.plot_coefs(tracers, 'plot_this', 'np.log(W1)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for tracer in tracers:
#       2     print(tracer['name'])
#       3     tracer['plot_this'] = np.log(tracer['W1']) # this shows lines artifact, very interesting
#
# NameError: name 'tracers' is not defined

# %%
for tracer in tracers:
    tracer['plot_this'] = np.log(tracer['S1']) # this shows a grid artifact, very interesting

hypyp.plots.plot_coefs(tracers, 'plot_this', 'np.log(S1)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for tracer in tracers:
#       2     tracer['plot_this'] = np.log(tracer['S1']) # this shows a grid artifact, very interesting
#       4 hypyp.plots.plot_coefs(tracers, 'plot_this', 'np.log(S1)')
#
# NameError: name 'tracers' is not defined

# %%
for tracer in tracers:
    tracer['plot_this'] = np.log(tracer['S1'] * tracer['S2']) # this shows a grid artifact, very interesting

hypyp.plots.plot_coefs(tracers, 'plot_this', 'np.log(S1*S2)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for tracer in tracers:
#       2     tracer['plot_this'] = np.log(tracer['S1'] * tracer['S2']) # this shows a grid artifact, very interesting
#       4 hypyp.plots.plot_coefs(tracers, 'plot_this', 'np.log(S1*S2)')
#
# NameError: name 'tracers' is not defined

# %%
plt.pcolormesh(np.abs(wtc_pywt)[:10,:])
plt.show()


plt.plot(np.abs(wtc_pywt)[0,:])
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.pcolormesh(np.abs(wct_pywt)[:10,:])
#       2 plt.show()
#       5 plt.plot(np.abs(wct_pywt)[0,:])
#
# NameError: name 'wct_pywt' is not defined

# %%
#len(tracer_pywt['psi_scales'])
plt.plot(np.real(tracer_pycwt['psi_scales'][10]))
plt.plot(np.imag(tracer_pycwt['psi_scales'][10]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #len(tracer_pywt['psi_scales'])
# ----> 2 plt.plot(np.real(tracer_pycwt['psi_scales'][10]))
#       3 plt.plot(np.imag(tracer_pycwt['psi_scales'][10]))
#
# NameError: name 'tracer_pycwt' is not defined

# %%
# only lower part
wavelet_name = 'cmor2-1'
tracer_pywt = dict(name='pywt')

wtc_pywt, times, freqs_pywt, coif_pywt = xwt_coherence_morl(
    y1,
    y2,
    T,
    1/12,
    wavelet_name=wavelet_name,
    normalize=True,
    smoothing_params=dict(smooth_factor=0),
    tracer=tracer_pywt
)

tracer_pycwt = dict(name='pywt')
wtc_pycwt, aWTC_pycwt, coi_pycwt, freqs_pycwt, significance_pycwt = pycwt.wct(y1, y2, dt=1/fs, sig=False, tracer=tracer_pycwt)

tracers = [tracer_pywt, tracer_pycwt]

for tracer in tracers:
    #tracer['plot_this'] = np.abs(tracer['S12']) ** 2
    tracer['plot_this'] = tracer['S1'] * tracer['S2']

hypyp.plots.plot_coefs(tracers, 'plot_this', 'plot_this')
#hypyp.plots.plot_coefs(tracers, 'S12', 'S12')
#hypyp.plots.plot_coefs(tracers, 'W1', 'W1')
#hypyp.plots.plot_coefs(tracers, 'W2', 'W2')
#hypyp.plots.plot_coefs(tracers, 'W12', 'W12')
#hypyp.plots.plot_coefs(tracers, 'S1', 'S1')
#hypyp.plots.plot_coefs(tracers, 'S2', 'S2')
#hypyp.plots.plot_coefs(tracers, 'S12', 'S12')

hypyp.plots.spectrogram_plot_period(np.abs(wtc_pywt), times, freqs_pywt, coif_pywt)
hypyp.plots.spectrogram_plot_period(np.abs(wtc_pycwt), times, freqs_pycwt, coif_pywt)

#get_frequencies(wavelet_name, freqs_pywt, T)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 wavelet_name = 'cmor2-1'
#       3 tracer_pywt = dict(name='pywt')
# ----> 5 wct_pywt, times, freqs_pywt, coif_pywt = xwt_coherence_morl(
#       6     y1,
#       7     y2,
#       8     T,
#       9     1/12,
#      10     wavelet_name=wavelet_name,
#      11     normalize=True,
#      12     smoothing_params=dict(smooth_factor=0),
#      13     tracer=tracer_pywt
#      14 )
#      16 tracer_pycwt = dict(name='pywt')
#      17 wct_pycwt, aWCT_pycwt, coi_pycwt, freqs_pycwt, significance_pycwt = pycwt.wct(y1, y2, dt=1/fs, sig=False, tracer=tracer_pycwt)
#
# File ~/work/ppsp/HyPyP-synchro/hypyp/fnirs_tools.py:453, in xwt_coherence_morl(y1, y2, dt, dj, wavelet_name, detrend, normalize, cwt_params, smoothing_params, tracer)
#     450 nOctaves = int(np.log2(2 * np.floor(N / 2.0)))
#     451 scales = 2 ** np.arange(1, nOctaves, dj)
# --> 453 W1, _ = pywt.cwt(y1_normal, scales, wavelet_name, method='fft', tracer=tracer, **cwt_params)
#     454 W2, _ = pywt.cwt(y2_normal, scales, wavelet_name, method='fft', **cwt_params)
#     456 #frequencies = freqs1
#
# TypeError: cwt() got an unexpected keyword argument 'tracer'
